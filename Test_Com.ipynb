# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
covid = pd.read_csv("https://covid19.ddc.moph.go.th/api/CSV/Cases/timeline-cases-by-provinces")
covid
# Out:
#       year  weeknum         province  new_case  total_case  \
# 0     2021       52           บึงกาฬ         7        2907
# 1     2021       52        เชียงใหม่        72       33971
# 2     2021       52           พัทลุง        50       14055
# 3     2021       52       ทั้งประเทศ      3011     2226446
# 4     2021       52           ชัยนาท         3        2973
# ...    ...      ...              ...       ...         ...
# 4182  2022       52  ประจวบคีรีขันธ์        17       45415
# 4183  2022       52         ปทุมธานี        33       88662
# 4184  2022       52       ปราจีนบุรี        31       52654
# 4185  2022       52      อุบลราชธานี        60       65412
# 4186  2022       52            ระนอง         1       20885
#
#       new_case_excludeabroad  total_case_excludeabroad  new_death  \
# 0                          7                      2907          0
# 1                         69                     33951          0
# ...

# %%
tax = pd.read_csv("https://catalog.excise.go.th/base/catalog/excise/file/03_0401.csv", encoding="utf-8", encoding_errors="ignore")
tax
# Out:
#      BUDGET_YEAR BUDGET_MONTH_DESC GROUP_NAME DUTY_NAME  \
# 0           2563                 Ҥ
# 1           2563                 Ҥ                    ҡ
# 2           2563                 Ҥ                    ҡ
# 3           2563                 Ҥ                    ҡ
# 4           2563                 Ҥ                    ҡ
# ..           ...               ...        ...       ...
# 580         2567                Ҿѹ                    ҡ
# 581         2567                Ҿѹ
# 582         2567                Ҿѹ
# 583         2567                Ҿѹ
# 584         2567                Ҿѹ
#
#               PRODUCT_NAME  TAX_NETTAX_AMT UPDATE_DATE
# 0                             1.787365e+04  2567-02-01
# 1               Դ ͡ҡ (1) Ѻ    3.129089e+09  2567-02-01
# 2                     ҡ蹪ԴҢ    2.602494e+09  2567-02-01
# 3            Ѻó ͡ҡ㹡صˡ 价ӡŧҾ    3.140866e+05  2567-02-01
# 4    Ѻ价ӡŧҾ 駹 ѡࡳ Ըա͹䢷͸ԺջСȡ˹    2.494863e+05  2567-02-01
# ..                     ...             ...         ...
# ...

# %%
gdp = pd.read_csv("")
gdp
# Out:
#                                          STRUCTURE_NAME ACTION    ACTIVITY  \
# 0     Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_NI_AP
# 1     Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_NI_AP
# 2     Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_NI_AP
# 3     Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_NI_AP
# 4     Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_NI_AP
# ...                                                 ...    ...         ...
# 8241  Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_D_CVM
# 8242  Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_D_CVM
# 8243  Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_D_CVM
# 8244  Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_D_CVM
# 8245  Quarterly Gross Domestic Products Gross Nation...      I  B1GQ_D_CVM
#
#                                            Main Account ECO_ACC  \
# ...

# %% [markdown]
# From: https://opendata.moac.go.th/?p=list-data&sp=list-data-info&id=0000000061

# %%
area = pd.read_csv("https://opendata.moac.go.th/subControl/downloadFile/downloadFile.php?id=0000000500")
area.tail(20)
# Out:
#        ปี          จังหวัด  พื้นที่ชุมชนและสิ่งปลูกสร้าง   พื้นที่นา  \
# 94   2561        กาญจนบุรี                         337391     439649
# 95   2561  ประจวบคีรีขันธ์                         230535      72826
# 96   2561         เพชรบุรี                         193918     415563
# 97   2561        กำแพงเพชร                         276114    1357854
# 98   2561         เชียงราย                         423948    1446452
# 99   2561        เชียงใหม่                         510952     589331
# 100  2561              ตาก                         189891     294710
# 101  2561        นครสวรรค์                         399030    2642943
# 102  2561             น่าน                         139022     226033
# 103  2561            พะเยา                         150485     745124
# 104  2561           พิจิตร                         211780    2087757
# 105  2561         พิษณุโลก                         369885    1699934
# 106  2561        เพชรบูรณ์                         370367    1306637
# ...

# %%
area.groupby("จังหวัด").sum().iloc[:,2:7].sort_values("พื้นที่นา", ascending=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4208\3528820197.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("จังหวัด").sum().iloc[:,2:7].sort_values("พื้นที่นา", ascending=False)
#              พื้นที่นา    พืชไร่   ไม้ยืนต้น   ไม้ผล   พืชสวน
# จังหวัด
# นครสวรรค์      5324814  3607954.0      163770  133756  84576.0
# อุบลราชธานี    4734233   692344.0      948313   56654  11819.0
# พิจิตร         4211392   365862.0       70734  236088  11750.0
# นครราชสีมา     4044133  4115236.0      373974  193212  30987.0
# ร้อยเอ็ด       3607077   377028.0      223369    6579   2780.0
# ...                ...        ...         ...     ...      ...
# พังงา            12459     3924.0     2075599   78287    347.0
# สมุทรสาคร        10119       17.0         617  111330  19858.0
# ...

# %%
phone_usage = pd.read_csv("https://catalogapi.nso.go.th/api/index?table=ICTH_43_02&format=csv")
phone_usage
# Out:
#      YEAR                    REGION             AREA      SEX  POP_TOTAL  \
# 0    2557          1) กรุงเทพมหานคร   1) ในเขตเทศบาล   1. ชาย  3870011.0
# 1    2557          1) กรุงเทพมหานคร   1) ในเขตเทศบาล  2. หญิง  4132114.0
# 2    2557                2) ภาคกลาง   1) ในเขตเทศบาล   1. ชาย  3935390.0
# 3    2557                2) ภาคกลาง   1) ในเขตเทศบาล  2. หญิง  4203327.0
# 4    2557                2) ภาคกลาง  2) นอกเขตเทศบาล   1. ชาย  4734797.0
# ..    ...                       ...              ...      ...        ...
# 139  2563  4) ภาคตะวันออกเฉียงเหนือ  2) นอกเขตเทศบาล  2. หญิง     6236.6
# 140  2563                 5) ภาคใต้   1) ในเขตเทศบาล   1. ชาย     1394.1
# 141  2563                 5) ภาคใต้   1) ในเขตเทศบาล  2. หญิง     1514.7
# 142  2563                 5) ภาคใต้  2) นอกเขตเทศบาล   1. ชาย     2847.2
# 143  2563                 5) ภาคใต้  2) นอกเขตเทศบาล  2. หญิง     2906.2
#
#      POP_USE_COM  POP_NOT_USE_COM  POP_USE_IN  POP_NOT_USE_IN  POP_USE_MO  \
# ...
