# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
df = pd.read_excel("")
df.head()
# Out:
#   กลุ่มโรคทางเดินหายใจ, 04 : [2251]  อัตราป่วยตาย (Fatality rate) ด้วยโรคปอดบวมทุกกลุ่มอายุ สิทธิ UC ของโรงพยาบาลที่ให้บริการ (hcode)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                    เขต 1 เชียงใหม่
# 4                                                NaN
#
#   Unnamed: 1         Unnamed: 2        Unnamed: 3         Unnamed: 4  \
# 0        NaN                NaN               NaN                NaN
# 1        NaN               2560               NaN                NaN
# 2        NaN  ตัวตั้ง (จังหวัด)  ตัวหาร (จังหวัด)  ผลลัพธ์ (จังหวัด)
# 3  เชียงใหม่                362              6041               5.99
# 4      ลำพูน                 69              1660               4.16
#
#              Unnamed: 5         Unnamed: 6        Unnamed: 7  \
# 0                   NaN                NaN               NaN
# ...
