# %% [markdown]
# >  # **Assignment 2**
# ---
# ## **Title :**  ผลกระทบของการย้ายถิ่นต่อสถานการณ์สังคมผู้สูงอายุ (aging society) ในประเทศไทย
# ## **Make by :** เสี่ยง
# > * 6441055226 ชินดนัย รุ่งโรจน์กิตติสิน
# > * 6441087326 ธนเทพ ศรีราตรี
# > * 6441194826 ภูมิภัทร ซิมอารีย์รัตน์

# %% [markdown]
#  > ## **Intro**
#  ---
# ในยุคปัจจุบัน การย้ายถิ่นฐานกลายเป็นปรากฏการณ์ทางสังคมที่พบเห็นได้ทั่วไป ผู้คนจากถิ่นกำเนิดหนึ่งเดินทางไปยังอีกถิ่นกำเนิดหนึ่งด้วยเหตุผลที่หลากหลาย เช่น การศึกษา การหางาน การแต่งงาน หรือเพื่อคุณภาพชีวิตที่ดีขึ้น
# ในประเทศไทย การย้ายถิ่นฐานเป็นปัจจัยสำคัญต่อการพัฒนาเศรษฐกิจและสังคม ผู้คนจากต่างจังหวัดย้ายเข้ามาอยู่ในเขตเมืองเพื่อหางานและโอกาสที่ดีกว่า ส่งผลให้เกิดการเปลี่ยนแปลงทางสังคม ซึ่งรวมถึงแม้กระทั่งสังคมผู้สูงอายุ  (aging society)
#
# วัตถุประสงค์ของการวิจัยครั้งนี้ คือ การเข้าไปสำรวจดูถึงสถานการณ์ aging society กับ พฤติกรรมการย้ายถิ่นฐานซึ่งสนใจกลุ่มอายุ 20-30 ปีซึ่งจะกลายเป็นกำลังหลักของครอบครัวในอนาคต โดยเกิดจากความสนใจที่ว่า สถานการณ์การย้ายถิ่นฐานในปัจจุบันมีแแนวโน้มเป็นอย่างไร และจะส่งผลอย่างไรต่อสังคมผู้สูงอายุของไทยในปัจจุบัน พร้อมทั้งนำเสนอสาเหตุและวิธีแก้ปัญหาเพื่อลดผลกระทบจากปัญหาดังกล่าวที่อาจจะเกิดขึ้นในอนาคต

# %% [markdown]
# > ## **Definition**
# ---
#
# *  **การย้ายถิ่น** หมายถึง การที่ย้ายสถานที่อยู่อาศัยจากเขตเทศบาลอื่นหรือ อบต.อื่น หรือจาก
# ประเทศอื่น ซึ่งเป็นที่อยู่อาศัยครั้งสุดท้ายมายังเขตเทศบาลหรือ อบต. ซึ่งเป็นพื้นที่ที่อยู่ปัจจุบัน
# การเปลี่ยนเขตเทศบาลหรือ อบต. เนื่องจาก การขยายเขตเทศบาลหรือแยกหมู่บ้าน โดยที่บุคคล
# หรือครัวเรือนนั้นยังอยู่ประจำที่เดิม และการย้ายสถานที่อยู่อาศัยในกรุงเทพมหานคร และเมืองพัทยา
# ไม่นับว่าเป็นการย้ายถิ่น
#
# * **ประชากรแฝง** หมายถึง ประชากรที่เข้ามาอยู่อาศัย มาเรียน หรือมาทำงานในพื้นที่หนึ่ง _แต่ไม่ได้ย้ายทะเบียนบ้านมาอยู่จริงในพื้นที่นั้น_ แบ่งออกได้เป็น 2 ประเภทหลัก ดังนี้
#
#     1. ประชากรแฝงกลางวัน (Commuter Population)
#         * หมายถึง ผู้ที่มีอายุตั้งแต่ 15 ปีขึ้นไป ที่เข้ามาทำงานหรือเรียนในพื้นที่หนึ่ง โดยไม่ได้ย้ายทะเบียนบ้านมาอยู่จริงในพื้นที่นั้น
#         * กลุ่มนี้มักเดินทางไปกลับระหว่างบ้านกับสถานที่ทำงานหรือสถานศึกษา
#         * ตัวอย่าง: คนที่อาศัยอยู่ในจังหวัดนนทบุรี แต่ทำงานในกรุงเทพฯ
#
#     2. ประชากรแฝงกลางคืน (Non-registered Population)
#         * หมายถึง ผู้ที่อาศัยอยู่ประจำในพื้นที่หนึ่ง โดยไม่มีชื่ออยู่ในทะเบียนบ้านในพื้นที่นั้น
#         * กลุ่มนี้มักมาจากต่างจังหวัด หรือต่างประเทศ
#         * สาเหตุที่ไม่ย้ายทะเบียนบ้าน อาจจะเพื่อสิทธิประโยชน์ในภูมิลำเนาเดิม หรือต้องการหลีกเลี่ยงภาระภาษี
#         * ตัวอย่าง: แรงงานข้ามชาติที่อาศัยและทำงานในกรุงเทพฯ
#
# * **aging society** หมายถึง  สังคมที่มีสัดส่วนของประชากรอายุ 60 ปีขึ้นไปมากกว่า 10% ของประชากรทั้งหมด หรือมีอายุ 65 ปีขึ้นไปมากกว่า 7% ของประชากรทั้งหมด (จากการสำรวจล่าสุดพบว่าประเทศไทยมีสัดส่วนของประชากรอายุ 60 ปีขึ้นไปประมาณ 18% ของประชากรทั้งหมด)
#
# * **เมืองโตเดี่ยว** หมายถึง เมืองที่มีขนาดใหญ่และมีประชากรอาศัยอยู่หนาแน่น ซึ่งมักเป็นศูนย์กลางของเศรษฐกิจ การเมือง และวัฒนธรรมของประเทศ ตัวอย่างเมืองโตเดี่ยวในประเทศไทยคือ กรุงเทพมหานคร

# %% [markdown]
#  # **Table of Content**
#  ---
#
# 1. [Prepare Data](#step-1--prepare-data)
# 2. [Data cleaning](#step-2--data-cleaning)
# 4. [Data analyze and graph explaination](#step-3--data-analyze-and-graph-explaination)
#     - ข้อมูลการย้ายถิ่นฐานแบ่งตามภาคและกรุงเทพฯ
#     - ข้อมูลการย้ายถิ่นฐานแบ่งตามเหตุผลที่ย้าย
#     - จำนวนประชากรแฝง
#     - จำนวนผู้สูงอายุที่อาศัยอยู่คนเดียว
# 5. [Causes and Solutions](#step-5--cause-and-solution)
# 6. [Summary](#step-6--summary)
#
# *(Outline ของกลุ่มเราอาจไม่ได้ follow ตาม [EDA Document](https://github.com/prasertcbs/454_2566/blob/main/EDA.md) แต่ใช้เป็น checklist ตอนทำ virtualisation แทน เนื่องจากกลุ่มเรามองว่างานวิจัยนี้ควรถูกเล่าตามเส้นเรื่อง (storytelling) ของตัวเองมากกว่า)*

# %% [markdown]
# # Step 1 : Prepare Data
# ---
#   > ## **Data listed**
#   รายการ datasets ที่ใช้ทั้งหมด มีดังนี้
#
#   * ข้อมูลการย้ายถิ่นฐาน แบ่งตามเหตุผลที่ย้ายและภูมิภาคที่ย้ายไป
#     * เหตุผลของการย้ายถิ่น_63
#     * เหตุผลของการย้ายถิ่น_64
#   * จำนวนผู้สูงอายุจากการสำรวจ จำแนกตามลักษณะการอยู่อาศัย กลุ่มอายุ เพศ
#   * อัตราเจริญพันธุ์รวมจากการสำรวจ
#   * ประชากรแฝงกลางคืน

# %% [markdown]
# # Step 2 : Data cleaning
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from ipywidgets import widgets, interact
import re
import io
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# SET YOUR PREFERRED FONT HERE
# sns.set_theme(font='Sukhumvit Set')
sns.set_theme(font='TH Sarabun New')

# %% [markdown]
# ## ข้อมูลการย้ายถิ่นฐาน แบ่งตามเหตุผลที่ย้ายและภูมิภาคที่ย้ายไป
#
# **แหล่งที่มาของข้อมูล**
# - [หน้าหลักของโครงการสำราจการย้ายถิ่นของประชากร สำนักงานสถิติแห่งชาติ (ตารางที่ 15)](https://nsodw.nso.go.th/dwportal/Item.aspx?p=w5RL2SpIlVgjBwBHiysW+A==)
# - เป็นข้อมูลที่ต้อง export ออกมาเท่านั้น (ไม่มีลิงค์ออนไลน์) ทางกลุ่มจึงได้อัพโหลดไว้บน Github ตามลิงค์ด้านล่างนี้
#     - [ข้อมูลของปี 63](https://github.com/Zylink2/Machine_Learning_Project_2/raw/main/files/%E0%B9%80%E0%B8%AB%E0%B8%95%E0%B8%B8%E0%B8%9C%E0%B8%A5%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A2%E0%B9%89%E0%B8%B2%E0%B8%A2%E0%B8%96%E0%B8%B4%E0%B9%88%E0%B8%99_63.csv)
#     - [ข้อมูลของปี 64](https://github.com/Zylink2/Machine_Learning_Project_2/raw/main/files/%E0%B9%80%E0%B8%AB%E0%B8%95%E0%B8%B8%E0%B8%9C%E0%B8%A5%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A2%E0%B9%89%E0%B8%B2%E0%B8%A2%E0%B8%96%E0%B8%B4%E0%B9%88%E0%B8%99_64.csv)

# %%
# import ข้อมูลและเพิ่มคอลัมเพื่อระบุปี
reasons_63 = pd.read_csv('https://github.com/Zylink2/Machine_Learning_Project_2/raw/main/files/%E0%B9%80%E0%B8%AB%E0%B8%95%E0%B8%B8%E0%B8%9C%E0%B8%A5%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A2%E0%B9%89%E0%B8%B2%E0%B8%A2%E0%B8%96%E0%B8%B4%E0%B9%88%E0%B8%99_63.csv')
reasons_63["Year"] = "2563"
# ข้อมูลจำนวนคนไม่สะท้อนความเป็นจริงมีการแสดงจุดทศนิยม จึงต้องมีการแก้ไขความถูกต้อง
reasons_63[["กรุงเทพมหานคร","กลาง","เหนือ","ตะวันออกเฉียงเหนือ","ใต้"]] = reasons_63[["กรุงเทพมหานคร","กลาง","เหนือ","ตะวันออกเฉียงเหนือ","ใต้"]].round()
reasons_63
# Out:
#       เหตุผลของการย้ายถิ่น  กรุงเทพมหานคร     กลาง    เหนือ  \
# 0                  หางานทำ        16098.0  34475.0   9882.0
# 1        ต้องการเปลี่ยนงาน         2649.0  15823.0   5193.0
# 2   ต้องการรายได้เพิ่มขึ้น         2018.0   7801.0   2879.0
# 3            หน้าที่การงาน         4064.0  26682.0  10324.0
# 4                 ศึกษาต่อ          497.0   3951.0   3561.0
# 5         ย้ายที่อยู่อาศัย         1567.0  50846.0   5822.0
# 6            กลับภูมิลำเนา         1781.0  13067.0  23140.0
# 7           ติดตามครอบครัว         2362.0  28206.0  15433.0
# 8     ช่วยธุรกิจในครอบครัว            NaN    364.0   1680.0
# 9                 รักษาตัว            NaN   1874.0     83.0
# 10               ขาดคนดูแล         1135.0   3642.0   2112.0
#
#     ตะวันออกเฉียงเหนือ      ใต้  Year
# 0              15859.0   8642.0  2563
# 1               6530.0   2058.0  2563
# 2                535.0    197.0  2563
# 3               2552.0   7836.0  2563
# 4               2094.0   2488.0  2563
# ...

# %%
# ตรวจสอบข้อมูลที่เป็น null หรือข้อมูลที่ขาดหายไปในตาราง จะพบว่าใน column กรุงเทพมีข้อมูลหายไป 2 แถว
reasons_63.isnull()
# Out:
#     เหตุผลของการย้ายถิ่น  กรุงเทพมหานคร   กลาง  เหนือ  ตะวันออกเฉียงเหนือ  \
# 0                  False          False  False  False               False
# 1                  False          False  False  False               False
# 2                  False          False  False  False               False
# 3                  False          False  False  False               False
# 4                  False          False  False  False               False
# 5                  False          False  False  False               False
# 6                  False          False  False  False               False
# 7                  False          False  False  False               False
# 8                  False           True  False  False               False
# 9                  False           True  False  False               False
# 10                 False          False  False  False               False
#
#       ใต้   Year
# 0   False  False
# 1   False  False
# 2   False  False
# ...

# %%
# ดูค่าทางสถิติต่างๆของตารางนี้ เพื่อนำไปใช้ในการเติมข้อมูลที่ขาดหายไป 
reasons_63.describe()
# Out:
#        กรุงเทพมหานคร          กลาง         เหนือ  ตะวันออกเฉียงเหนือ  \
# count       9.000000     11.000000     11.000000           11.000000
# mean     3574.555556  16975.545455   7282.636364        10769.909091
# std      4802.290160  16204.865562   6954.088010        15443.097665
# min       497.000000    364.000000     83.000000          535.000000
# 25%      1567.000000   3796.500000   2495.500000         1636.500000
# 50%      2018.000000  13067.000000   5193.000000         4700.000000
# 75%      2649.000000  27444.000000  10103.000000        13793.000000
# max     16098.000000  50846.000000  23140.000000        53217.000000
#
#                 ใต้
# count     11.000000
# mean    7403.545455
# std     8380.134490
# min      123.000000
# 25%     1419.000000
# 50%     2488.000000
# 75%    11657.500000
# max    25566.000000

# %%
# เมื่อดูจากข้อมูลในแถวอื่นๆ ทางเราตัดสินใจว่าจะใช้ค่า percentile ที่ 25 ในการเติมข้อมูลจึงจะมีความเหมาะสมมากที่สุด
reasons_63.fillna(reasons_63["กรุงเทพมหานคร"].quantile(0.25), inplace=True)
reasons_63
# Out:
#       เหตุผลของการย้ายถิ่น  กรุงเทพมหานคร     กลาง    เหนือ  \
# 0                  หางานทำ        16098.0  34475.0   9882.0
# 1        ต้องการเปลี่ยนงาน         2649.0  15823.0   5193.0
# 2   ต้องการรายได้เพิ่มขึ้น         2018.0   7801.0   2879.0
# 3            หน้าที่การงาน         4064.0  26682.0  10324.0
# 4                 ศึกษาต่อ          497.0   3951.0   3561.0
# 5         ย้ายที่อยู่อาศัย         1567.0  50846.0   5822.0
# 6            กลับภูมิลำเนา         1781.0  13067.0  23140.0
# 7           ติดตามครอบครัว         2362.0  28206.0  15433.0
# 8     ช่วยธุรกิจในครอบครัว         1567.0    364.0   1680.0
# 9                 รักษาตัว         1567.0   1874.0     83.0
# 10               ขาดคนดูแล         1135.0   3642.0   2112.0
#
#     ตะวันออกเฉียงเหนือ      ใต้  Year
# 0              15859.0   8642.0  2563
# 1               6530.0   2058.0  2563
# 2                535.0    197.0  2563
# 3               2552.0   7836.0  2563
# 4               2094.0   2488.0  2563
# ...

# %%
# import ข้อมูล แก้ไขชื่อของคอลัมแรกเพื่อใช้ในการรวมตาราง และเพิ่มคอลัมเพื่อระบุปี
reasons_64 = pd.read_csv('https://github.com/Zylink2/Machine_Learning_Project_2/raw/main/files/%E0%B9%80%E0%B8%AB%E0%B8%95%E0%B8%B8%E0%B8%9C%E0%B8%A5%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A2%E0%B9%89%E0%B8%B2%E0%B8%A2%E0%B8%96%E0%B8%B4%E0%B9%88%E0%B8%99_64.csv')
reasons_64.rename(columns={"เหตุผลของการย้ายถิ่น 2564":"เหตุผลของการย้ายถิ่น"}, inplace=True)
reasons_64["Year"] = "2564"
# ข้อมูลจำนวนคนไม่สะท้อนความเป็นจริงมีการแสดงจุดทศนิยม จึงต้องมีการแก้ไขความถูกต้องเช่นเดียวกับปี 2563
reasons_64[["กรุงเทพมหานคร","กลาง","เหนือ","ตะวันออกเฉียงเหนือ","ใต้"]] = reasons_64[["กรุงเทพมหานคร","กลาง","เหนือ","ตะวันออกเฉียงเหนือ","ใต้"]].apply(lambda x : x.str.strip().str.replace(",","")).astype(float).round()
reasons_64
# Out:
#       เหตุผลของการย้ายถิ่น  กรุงเทพมหานคร     กลาง    เหนือ  \
# 0            กลับภูมิลำเนา         2032.0  15369.0  31706.0
# 1           ติดตามครอบครัว         4628.0  33976.0  24396.0
# 2                  หางานทำ        30752.0  47436.0   5248.0
# 3         ย้ายที่อยู่อาศัย         1312.0  44906.0   9912.0
# 4            หน้าที่การงาน         2707.0  32481.0   6054.0
# 5        ต้องการเปลี่ยนงาน         1730.0  15664.0   5649.0
# 6                 ศึกษาต่อ         1100.0   2375.0   5867.0
# 7                ขาดคนดูแล          883.0   4102.0   2747.0
# 8     ช่วยธุรกิจในครอบครัว         3859.0   1940.0   1920.0
# 9                 รักษาตัว            NaN    601.0    489.0
# 10  ต้องการรายได้เพิ่มขึ้น            NaN   2478.0    421.0
#
#     ตะวันออกเฉียงเหนือ      ใต้  Year
# 0              78988.0  24152.0  2564
# 1              27694.0  27996.0  2564
# 2               4504.0  10516.0  2564
# 3              19393.0  16995.0  2564
# 4               6766.0   7356.0  2564
# ...

# %%
# ตรวจสอบข้อมูลที่เป็น null หรือข้อมูลที่ขาดหายไปในตาราง จะพบว่าใน column กรุงเทพมีข้อมูลหายไป 2 แถว
reasons_64.isnull()
# Out:
#     เหตุผลของการย้ายถิ่น  กรุงเทพมหานคร   กลาง  เหนือ  ตะวันออกเฉียงเหนือ  \
# 0                  False          False  False  False               False
# 1                  False          False  False  False               False
# 2                  False          False  False  False               False
# 3                  False          False  False  False               False
# 4                  False          False  False  False               False
# 5                  False          False  False  False               False
# 6                  False          False  False  False               False
# 7                  False          False  False  False               False
# 8                  False          False  False  False               False
# 9                  False           True  False  False               False
# 10                 False           True  False  False               False
#
#       ใต้   Year
# 0   False  False
# 1   False  False
# 2   False  False
# ...

# %%
# ดูค่าทางสถิติต่างๆของตารางนี้ เพื่อนำไปใช้ในการเติมข้อมูลที่ขาดหายไป 
reasons_64.describe()
# Out:
#        กรุงเทพมหานคร          กลาง         เหนือ  ตะวันออกเฉียงเหนือ  \
# count       9.000000     11.000000     11.000000           11.000000
# mean     5444.777778  18302.545455   8582.636364        14070.272727
# std      9574.354610  18181.285347  10151.743498        23118.805376
# min       883.000000    601.000000    421.000000          117.000000
# 25%      1312.000000   2426.500000   2333.500000         3575.500000
# 50%      2032.000000  15369.000000   5649.000000         4792.000000
# 75%      3859.000000  33228.500000   7983.000000        13079.500000
# max     30752.000000  47436.000000  31706.000000        78988.000000
#
#                 ใต้
# count     11.000000
# mean    9083.363636
# std     9844.160444
# min      133.000000
# 25%     1272.500000
# 50%     6017.000000
# 75%    13755.500000
# max    27996.000000

# %%
# เมื่อดูจากข้อมูลในแถวอื่นๆ ทางเราตัดสินใจว่าจะใช้ค่า percentile ที่ 25 ในการเติมข้อมูลจึงจะมีความเหมาะสมมากที่สุด
reasons_64.fillna(reasons_64["กรุงเทพมหานคร"].quantile(0.25), inplace=True)
reasons_64
# Out:
#       เหตุผลของการย้ายถิ่น  กรุงเทพมหานคร     กลาง    เหนือ  \
# 0            กลับภูมิลำเนา         2032.0  15369.0  31706.0
# 1           ติดตามครอบครัว         4628.0  33976.0  24396.0
# 2                  หางานทำ        30752.0  47436.0   5248.0
# 3         ย้ายที่อยู่อาศัย         1312.0  44906.0   9912.0
# 4            หน้าที่การงาน         2707.0  32481.0   6054.0
# 5        ต้องการเปลี่ยนงาน         1730.0  15664.0   5649.0
# 6                 ศึกษาต่อ         1100.0   2375.0   5867.0
# 7                ขาดคนดูแล          883.0   4102.0   2747.0
# 8     ช่วยธุรกิจในครอบครัว         3859.0   1940.0   1920.0
# 9                 รักษาตัว         1312.0    601.0    489.0
# 10  ต้องการรายได้เพิ่มขึ้น         1312.0   2478.0    421.0
#
#     ตะวันออกเฉียงเหนือ      ใต้  Year
# 0              78988.0  24152.0  2564
# 1              27694.0  27996.0  2564
# 2               4504.0  10516.0  2564
# 3              19393.0  16995.0  2564
# 4               6766.0   7356.0  2564
# ...

# %%
# รวม 2 ตารางเข้าด้วยกันเพื่อใช้ในการวิเคราะห์ต่อไป
reasons_6364 = pd.concat([reasons_63, reasons_64], ignore_index=True)
reasons_6364
# Out:
#       เหตุผลของการย้ายถิ่น  กรุงเทพมหานคร     กลาง    เหนือ  \
# 0                  หางานทำ        16098.0  34475.0   9882.0
# 1        ต้องการเปลี่ยนงาน         2649.0  15823.0   5193.0
# 2   ต้องการรายได้เพิ่มขึ้น         2018.0   7801.0   2879.0
# 3            หน้าที่การงาน         4064.0  26682.0  10324.0
# 4                 ศึกษาต่อ          497.0   3951.0   3561.0
# 5         ย้ายที่อยู่อาศัย         1567.0  50846.0   5822.0
# 6            กลับภูมิลำเนา         1781.0  13067.0  23140.0
# 7           ติดตามครอบครัว         2362.0  28206.0  15433.0
# 8     ช่วยธุรกิจในครอบครัว         1567.0    364.0   1680.0
# 9                 รักษาตัว         1567.0   1874.0     83.0
# 10               ขาดคนดูแล         1135.0   3642.0   2112.0
# 11           กลับภูมิลำเนา         2032.0  15369.0  31706.0
# 12          ติดตามครอบครัว         4628.0  33976.0  24396.0
# 13                 หางานทำ        30752.0  47436.0   5248.0
# 14        ย้ายที่อยู่อาศัย         1312.0  44906.0   9912.0
# ...

# %%
# เปลี่ยนรูปแบบของตารางจาก wide format เป็น long format เพื่อความง่ายในการสร้างกราฟ และวิเคราะห์ข้อมูล
reasons_6364 = pd.melt(reasons_6364,id_vars=["เหตุผลของการย้ายถิ่น","Year"],var_name="Region", value_name="People").copy()
reasons_6364
# Out:
#        เหตุผลของการย้ายถิ่น  Year         Region   People
# 0                   หางานทำ  2563  กรุงเทพมหานคร  16098.0
# 1         ต้องการเปลี่ยนงาน  2563  กรุงเทพมหานคร   2649.0
# 2    ต้องการรายได้เพิ่มขึ้น  2563  กรุงเทพมหานคร   2018.0
# 3             หน้าที่การงาน  2563  กรุงเทพมหานคร   4064.0
# 4                  ศึกษาต่อ  2563  กรุงเทพมหานคร    497.0
# ..                      ...   ...            ...      ...
# 105                ศึกษาต่อ  2564            ใต้   6017.0
# 106               ขาดคนดูแล  2564            ใต้   3853.0
# 107    ช่วยธุรกิจในครอบครัว  2564            ใต้    133.0
# 108                รักษาตัว  2564            ใต้    377.0
# 109  ต้องการรายได้เพิ่มขึ้น  2564            ใต้    354.0
#
# [110 rows x 4 columns]

# %%
# สร้าง function เพื่อใช้ในการแปลจากข้อมูลภาษาไทยให้เป็นภาษาอังกฤษเพื่อให้อ่านได้ง่ายขึ้นจากทุก users
def translate_1(val):
    if val == "กรุงเทพมหานคร":
        return "Bangkok"
    elif val == "กลาง":
        return "Central"
    elif val == "เหนือ":
        return "North"
    elif val == "ตะวันออกเฉียงเหนือ":
        return "Notheast"
    else:
        return "South"

def translate_2(val):
    if val == "หางานทำ":
        return "Looking for a job"
    elif val == "ต้องการเปลี่ยนงาน":
        return "Changing job"
    elif val == "ต้องการรายได้เพิ่มขึ้น":
        return "Need more revenue"
    elif val == "หน้าที่การงาน":
        return "Responsibility"
    elif val == "ศึกษาต่อ":
        return "Graduating"
    elif val == "ย้ายที่อยู่อาศัย":
        return "Moving out"
    elif val == "กลับภูมิลำเนา":
        return "Going back home"
    elif val == "ติดตามครอบครัว":
        return "Following family"
    elif val == "ช่วยธุรกิจในครอบครัว":
        return "Helping family business"
    elif val == "รักษาตัว":
        return "Recovering"
    elif val == "ขาดคนดูแล":
        return "Lacking of care person"
    else:
        return "Others"

# %%
# ใช้ function apply และ lambda ช่วยในการแปลภาษาข้อมูลหลายแถว
reasons_6364["Region"] = reasons_6364["Region"].apply(lambda x: translate_1(x))
reasons_6364.rename(columns={"เหตุผลของการย้ายถิ่น":"Immigration Reason"}, inplace=True)
reasons_6364["Immigration Reason"] = reasons_6364["Immigration Reason"].apply(lambda x : translate_2(x))
reasons_6364
# Out:
#           Immigration Reason  Year   Region   People
# 0          Looking for a job  2563  Bangkok  16098.0
# 1               Changing job  2563  Bangkok   2649.0
# 2          Need more revenue  2563  Bangkok   2018.0
# 3             Responsibility  2563  Bangkok   4064.0
# 4                 Graduating  2563  Bangkok    497.0
# ..                       ...   ...      ...      ...
# 105               Graduating  2564    South   6017.0
# 106   Lacking of care person  2564    South   3853.0
# 107  Helping family business  2564    South    133.0
# 108               Recovering  2564    South    377.0
# 109        Need more revenue  2564    South    354.0
#
# [110 rows x 4 columns]

# %% [markdown]
# ## จำนวนผู้สูงอายุจากการสำรวจ จำแนกตามลักษณะการอยู่อาศัย กลุ่มอายุ เพศ
#
# แหล่งที่มาของข้อมูล
# - [หน้าหลักของข้อมูล จากสำนักงานสถิติแห่งชาติ](https://catalog.nso.go.th/dataset/os_01_00045/resource/c7b3b266-a884-47e1-b042-5d8eccce7d69)
# - [ลิงค์ข้อมูล](https://catalogapi.nso.go.th/api/index?table=OS_01_0045_15&format=csv)

# %%
# อ่านข้อมูลจาก source ด้านบน
elders = pd.read_csv("https://catalogapi.nso.go.th/api/index?table=OS_01_0045_15&format=csv", encoding='utf-8')
elders.head(20)
# Out:
#     year   sex    age_group type_of_con_mat    value unit  \
# 0   2545   รวม          รวม             รวม  5969030   คน
# 1   2545   รวม     60-64 ปี             รวม  2073244   คน
# 2   2545   รวม     65-69 ปี             รวม  1668666   คน
# 3   2545   รวม     70-74 ปี             รวม  1101189   คน
# 4   2545   รวม  75 ปีขึ้นไป             รวม  1125932   คน
# 5   2545   ชาย          รวม             รวม  2729095   คน
# 6   2545   ชาย     60-64 ปี             รวม   975344   คน
# 7   2545   ชาย     65-69 ปี             รวม   773955   คน
# 8   2545   ชาย     70-74 ปี             รวม   500762   คน
# 9   2545   ชาย  75 ปีขึ้นไป             รวม   479034   คน
# 10  2545  หญิง          รวม             รวม  3239935   คน
# 11  2545  หญิง     60-64 ปี             รวม  1097900   คน
# 12  2545  หญิง     65-69 ปี             รวม   894711   คน
# 13  2545  หญิง     70-74 ปี             รวม   600426   คน
# 14  2545  หญิง  75 ปีขึ้นไป             รวม   646898   คน
# ...

# %%
# เนื่องจากข้อมูลปี 2545 มี range ของข้อมูล age group ที่ไม่สอดคล้องกับปีอื่นๆ จึงต้องมีการ query ข้อมูลออก
elders = elders[elders["year"] != 2545].copy()
elders
# Out:
#      year   sex    age_group type_of_con_mat     value unit  \
# 45   2550   รวม          รวม             รวม   7020959   คน
# 46   2550   รวม     60-69 ปี             รวม   4125253   คน
# 47   2550   รวม     70-79 ปี             รวม   2226712   คน
# 48   2550   รวม  80 ปีขึ้นไป             รวม    668994   คน
# 49   2550   ชาย          รวม             รวม   3130736   คน
# ..    ...   ...          ...             ...       ...  ...
# 157  2564   ชาย          รวม     อยู่คนเดียว    610656   คน
# 158  2564  หญิง          รวม     อยู่คนเดียว    990759   คน
# 159  2564  รวม           รวม      อยู่หลายคน  11757336   คน
# 160  2564   ชาย          รวม      อยู่หลายคน   5363366   คน
# 161  2564  หญิง          รวม      อยู่หลายคน   6393970   คน
#
#                     source
# 45   สำนักงานสถิติแห่งชาติ
# 46   สำนักงานสถิติแห่งชาติ
# 47   สำนักงานสถิติแห่งชาติ
# 48   สำนักงานสถิติแห่งชาติ
# 49   สำนักงานสถิติแห่งชาติ
# ..                     ...
# 157  สำนักงานสถิติแห่งชาติ
# ...

# %%
# สร้าง function เพื่อใช้ในการแปลจากข้อมูลภาษาไทยให้เป็นภาษาอังกฤษเพื่อให้อ่านได้ง่ายขึ้นจากทุก users
def translate_3(val):
    if val == "รวม":
        return "All"
    elif val == "ชาย":
        return "Male"
    elif val == "หญิง":
        return "Female"
    else:
        return "Others"

def translate_4(val):
    if val == "รวม":
        return "All"
    elif val == "60-69 ปี":
        return "60-69 yrs old"
    elif val == "70-79 ปี":
        return "70-79 yrs old"
    elif val == "80 ปีขึ้นไป":
        return "80+ yrs old"
    else:
        return "Others"

def translate_5(val):
    if val == "รวม":
        return "All"
    elif val == "อยู่คนเดียว":
        return "Alone"
    elif val == "อยู่หลายคน":
        return "Not alone"
    else:
        return "Others"

# %%
# ตรวจสอบข้อมูลที่ต้องการจะแปลทั้ง 3 คอลัมว่า ไม่มีช่องว่างนำหน้าหรือต่อท้ายในข้อมูล ที่อาจทำให้การเปลี่ยนภาษามีการผิดพลาดได้
elders[['sex', 'age_group','type_of_con_mat']] = elders[['sex', 'age_group','type_of_con_mat']].apply(lambda x: x.str.strip())
# ใช้ function apply และ lambda ช่วยในการแปลภาษาข้อมูลหลายแถว
elders['sex'] = elders['sex'].apply(lambda x : translate_3(x))
elders['age_group'] = elders['age_group'].apply(lambda x : translate_4(x))
elders['type_of_con_mat'] = elders['type_of_con_mat'].apply(lambda x : translate_5(x))
# เราต้องการพูดถึงประเด็นกลุ่มผู้สูงอายุที่อยู่คนเดียว และ ต้องการข้อมูลอายุช่วง 60 ปีขึ้นไป จึงต้อง query ข้อมูล
elders = elders[(elders['type_of_con_mat'] == 'Alone') & (elders['age_group'] != 'All') & (elders['sex'] != 'All')].copy()
# drop คอลัมที่ไม่จำเป็น
elders.drop(columns=["unit","source"], inplace=True)
elders
# Out:
#      year     sex      age_group type_of_con_mat   value
# 62   2550    Male  60-69 yrs old           Alone   87756
# 63   2550    Male  70-79 yrs old           Alone   81477
# 64   2550    Male    80+ yrs old           Alone   21001
# 66   2550  Female  60-69 yrs old           Alone  168659
# 67   2550  Female  70-79 yrs old           Alone  132351
# 68   2550  Female    80+ yrs old           Alone   46761
# 98   2557    Male  60-69 yrs old           Alone  164865
# 99   2557    Male  70-79 yrs old           Alone   98820
# 100  2557    Male    80+ yrs old           Alone   55037
# 102  2557  Female  60-69 yrs old           Alone  266585
# 103  2557  Female  70-79 yrs old           Alone  200501
# 104  2557  Female    80+ yrs old           Alone   90190
# 134  2560    Male  60-69 yrs old           Alone  224965
# 135  2560    Male  70-79 yrs old           Alone  137137
# 136  2560    Male    80+ yrs old           Alone   67868
# ...

# %% [markdown]
# ## ประชากรแฝงกลางคืน
#
# แหล่งที่มาของข้อมูล
# - [หน้าหลักของข้อมูลสำรวจประชากรแฝง](https://www.nso.go.th/nsoweb/nso/survey_detail/yS)
# - เนื่องจากมีเพียงไฟล์ประเภท pdf เท่านั้น ทางกลุ่มจึงต้องรวบรวมจำนวนประชากรแฝงกลางคืนในกรุงเทพมหานคร 6 ปีย้อนหลังโดยการเปิดรายงานทุกฉบับ เลือกเพียงข้อมูลที่สนใจ แล้วบันทึกในรูป text
#     - [รายงานสำรวจประชากรแฝงปี 2565](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMTU4NDRfNzA0NjUucGRmIiwiZmlsZW5hbWUiOiJzdW1tYXJ5XzY1LnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2564](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMTU5MzBfODYyODYucGRmIiwiZmlsZW5hbWUiOiJzdW1tYXJ5XzY0LnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2563](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAwMjFfMjIyODIucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYzLnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2562](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAxMjFfMzYzNjgucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYyLnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2561](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAxNTRfNzY2MjcucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYxLnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2560](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAyMjhfNjg3NjcucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYwLnBkZiJ9)

# %%
# นำข้อมูลจากไฟล์ pdf มาใส่ในตัวแปร text
text="""ตารางที่ 2 จำนวนประชากรแฝงในกรุงเทพ
หน่วย : พันคน 
จังหวัด,ปี,จำนวนประชากรแฝงกลางคืน
กรุงเทพมหานคร,2565,2.708
กรุงเทพมหานคร,2564,2.324
กรุงเทพมหานคร,2563,2.35
กรุงเทพมหานคร,2562,2.27
กรุงเทพมหานคร,2561,2.04
กรุงเทพมหานคร,2560,2.05
"""

# %%
# อ่านข้อมูลที่เป็น text จากตัวแปรข้างบน
night_pop = pd.read_csv(io.StringIO(text), skiprows=2)
# แปลภาษาของชื่อคอลัม
night_pop.rename(columns={"จังหวัด":"City", "ปี":"Year", "จำนวนประชากรแฝงกลางคืน":"Nighttime Shadow Population"}, inplace=True)
# แปลภาษาข้อมูลในคอลัม City
night_pop["City"] = night_pop["City"].str.replace("กรุงเทพมหานคร", "Bangkok")
night_pop
# Out:
#       City  Year  Nighttime Shadow Population
# 0  Bangkok  2565                        2.708
# 1  Bangkok  2564                        2.324
# 2  Bangkok  2563                        2.350
# 3  Bangkok  2562                        2.270
# 4  Bangkok  2561                        2.040
# 5  Bangkok  2560                        2.050

# %% [markdown]
# ## อัตราเจริญพันธุ์
#
# แหล่งที่มาของข้อมูล
# - [หน้าหลักของข้อมูล จากสำนักงานสถิติแห่งชาติ](https://catalog.nso.go.th/dataset/os_01_00038/resource/bdd726a6-6c30-4081-b4d1-cbd5a45457dd)
# - [ลิงค์ข้อมูล](https://catalogapi.nso.go.th/api/index?table=OS_01_0038_01&format=csv)

# %%
# อ่านข้อมูลจาก source ด้านบน
fertility = pd.read_csv('https://catalogapi.nso.go.th/api/index?table=OS_01_0038_01&format=csv')
# แปลภาษาของชื่อคอลัม
fertility.rename(columns={"value":"percentage"}, inplace=True)
fertility
# Out:
#         year  percentage                                        unit  \
# 0  2517-2519        4.90  คนต่อสตรีวัยเจริญพันธุ์ (15-49 ปี) หนึ่งคน
# 1  2528-2529        2.70  คนต่อสตรีวัยเจริญพันธุ์ (15-49 ปี) หนึ่งคน
# 2  2538-2539        2.00  คนต่อสตรีวัยเจริญพันธุ์ (15-49 ปี) หนึ่งคน
# 3  2548-2549        1.50  คนต่อสตรีวัยเจริญพันธุ์ (15-49 ปี) หนึ่งคน
# 4  2558-2559        1.61  คนต่อสตรีวัยเจริญพันธุ์ (15-49 ปี) หนึ่งคน
#
#                   source
# 0  สำนักงานสถิติแห่งชาติ
# 1  สำนักงานสถิติแห่งชาติ
# 2  สำนักงานสถิติแห่งชาติ
# 3  สำนักงานสถิติแห่งชาติ
# 4  สำนักงานสถิติแห่งชาติ

# %% [markdown]
# # Step 3 : Data analyze and graph explaination
# ----

# %% [markdown]
# ## ข้อมูลการย้ายถิ่นฐาน แบ่งตามเหตุผลที่ย้ายและภูมิภาคที่ย้ายไป ปี 2563 - 2564
#
# **แหล่งที่มาของข้อมูล**
# - [หน้าหลักของโครงการสำราจการย้ายถิ่นของประชากร สำนักงานสถิติแห่งชาติ (ตารางที่ 15)](https://nsodw.nso.go.th/dwportal/Item.aspx?p=w5RL2SpIlVgjBwBHiysW+A==)
# - เป็นข้อมูลที่ต้อง export ออกมาเท่านั้น (ไม่มีลิงค์ออนไลน์) ทางกลุ่มจึงได้อัพโหลดไว้บน Github ตามลิงค์ด้านล่างนี้
#     - [ข้อมูลของปี 63](https://github.com/Zylink2/Machine_Learning_Project_2/raw/main/files/%E0%B9%80%E0%B8%AB%E0%B8%95%E0%B8%B8%E0%B8%9C%E0%B8%A5%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A2%E0%B9%89%E0%B8%B2%E0%B8%A2%E0%B8%96%E0%B8%B4%E0%B9%88%E0%B8%99_63.csv)
#     - [ข้อมูลของปี 64](https://github.com/Zylink2/Machine_Learning_Project_2/raw/main/files/%E0%B9%80%E0%B8%AB%E0%B8%95%E0%B8%B8%E0%B8%9C%E0%B8%A5%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A2%E0%B9%89%E0%B8%B2%E0%B8%A2%E0%B8%96%E0%B8%B4%E0%B9%88%E0%B8%99_64.csv)
# ---
#
# เริ่มจากการเข้าไปสำรวจดูว่าสถิติการย้ายถิ่นฐานที่ได้มีการสำรวจล่าสุดนั้นมีลักษณะเป็นอย่างไร โดยจะแบ่งย่อยเป็นสองมิติ ได้แก่
# - ข้อมูลการย้านถิ่นฐานที่แบ่งตามภาคและกรุงเทพฯ
# - ช้อมูลการย้านถิ่นฐานที่แบ่งตามเหตุผลที่ย้ายออกไป
#
# โดยจะเริ่มจากแบ่งตามภูมิภาค โดยมีตารางสรุปและกราฟที่ใช้นำเสนอดังนี้

# %% [markdown]
# ### แบ่งตามภาคและกรุงเทพฯ

# %%
df = pd.DataFrame(reasons_6364.groupby(["Year", "Region"])['People'].sum())
df.sort_values(by=['Year','People'], ascending=[True, False])
# Out:
#                  People
# Year Region
# 2563 Central   186731.0
#      Notheast  118469.0
#      South      81439.0
#      North      80109.0
#      Bangkok    35305.0
# 2564 Central   201328.0
#      Notheast  154773.0
#      South      99917.0
#      North      94409.0
#      Bangkok    51627.0

# %%
order = reasons_6364[reasons_6364['Year'] == '2564'].groupby('Region')['People'].sum().sort_values().index.tolist()

migrate_region = sns.barplot(
    data = reasons_6364, 
    order = order, 
    hue="Year", 
    x="Region", 
    y="People", 
    errorbar=None, 
    palette="Greys",
    estimator=sum)

migrate_region.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f"{x/1000:,.0f}K"))
plt.title("Increase of Migration in Thailand across all regions between 2563 and 2564", fontdict={'fontsize': 18})
sns.move_legend(migrate_region, "upper left", bbox_to_anchor=(1, 1));

# %% [markdown]
# **จาก  bar graph ข้างต้น จะพบว่ามีจำนวนผู้ย้ายถิ่นฐานในประเทศไทยมีจำนวนเพิ่มขึ้นในทุกภาค ในปี 2564 เมื่อเปรียบเทียบกับปี 2563 โดยภาคที่มีจำนวนผู้ย้ายถิ่นฐานมากที่สุดคือภาคกลาง รองลงมาคือ ภาคตะวันออกเฉียงเหนือ ภาคใต้และภาคเหนือ ตามลำดับ โดยมีกรุงเทพอยู่ที่ลำดับสุดท้าย โดยมีผู้อพยบเข้าอยู่ที่ ประมาณ 35,000 คน และ 52,000 ในปี 2563 และ 2564 ตามลำดับ**

# %% [markdown]
# ### แบ่งตามเหตุผล
#
# **แต่เพียงตัวเลขภาพรวมอาจยังไม่สามารถบอกสาเหตุได้ เราถึงขอนำเสนออีกหนึ่งมุมมองจาก dataset เดียวกัน เพื่อนำเสนอเหตุผลยอดนิยมที่คนย้ายถิ่นฐานกัน**

# %%
pivot_reason = reasons_6364.pivot_table(index=['Year', 'Immigration Reason'], columns='Region', values='People')
pivot_reason['Total'] = reasons_6364.pivot_table(index = ['Year', 'Immigration Reason'], values='People')
pivot_reason.sort_values(by=['Year','Total'], ascending=[True, False])
# Out:
# Region                        Bangkok  Central    North  Notheast    South  \
# Year Immigration Reason
# 2563 Going back home           1781.0  13067.0  23140.0   53217.0  25566.0
#      Looking for a job        16098.0  34475.0   9882.0   15859.0   8642.0
#      Moving out                1567.0  50846.0   5822.0   11727.0  14673.0
#      Following family          2362.0  28206.0  15433.0   19007.0  16858.0
#      Responsibility            4064.0  26682.0  10324.0    2552.0   7836.0
#      Changing job              2649.0  15823.0   5193.0    6530.0   2058.0
#      Lacking of care person    1135.0   3642.0   2112.0    4700.0   2218.0
#      Need more revenue         2018.0   7801.0   2879.0     535.0    197.0
#      Graduating                 497.0   3951.0   3561.0    2094.0   2488.0
#      Recovering                1567.0   1874.0     83.0    1179.0    780.0
#      Helping family business   1567.0    364.0   1680.0    1069.0    123.0
# ...

# %%
@interact(Region=reasons_6364['Region'].unique())
def plot_chart(Region=reasons_6364['Region'].unique()):
    filtered_data = reasons_6364[reasons_6364['Region'] == Region]
    
    interact_region = sns.catplot(
        data=filtered_data.sort_values("People", ascending=False),
        kind="bar",
        y="Immigration Reason",
        x="People",
        color=".7",
        col="Year",
        errorbar=None,
        palette="Reds_r",
        height=3.5,
        aspect=1.6,
        sharex=True
    )
    
    def thousands_formatter(x, pos):
        return f"{x/1000:.0f}K"

    for ax in interact_region.axes.flat:
        ax.xaxis.set_major_formatter(ticker.FuncFormatter(thousands_formatter))
        ax.set_ylabel("")
        ax.set_title(re.sub(".* = ", "", ax.get_title()))
# Out:
# interactive(children=(Dropdown(description='Region', options=('Bangkok', 'Central', 'North', 'Notheast', 'Sout…

# %%
@interact(Region=reasons_6364['Region'].unique())
def plot_chart(Region=reasons_6364['Region'].unique()):
    filtered_data = reasons_6364[reasons_6364['Region'] == Region]
    
    interact_region = sns.catplot(
        data=filtered_data.sort_values("People", ascending=False),
        kind="bar",
        y="Immigration Reason",
        x="People",
        color=".7",
        col="Year",
        errorbar=None,
        palette="Greys_r",
        height=3.5,
        aspect=1.6,
        sharex=True,
    )
    
    def thousands_formatter(x, pos):
        return f"{x/1000:.0f}K"

    for ax in interact_region.axes.flat:
        ax.xaxis.set_major_formatter(ticker.FuncFormatter(thousands_formatter))
        ax.set_ylabel("")
        ax.set_title(re.sub(".* = ", "", ax.get_title()))
# Out:
# interactive(children=(Dropdown(description='Region', options=('Bangkok', 'Central', 'North', 'Notheast', 'Sout…

# %%
reasons_go_home = pd.DataFrame(reasons_6364[reasons_6364['Immigration Reason']== 'Going back home'].groupby(['Year'])['People'].sum())
reasons_go_home.rename(columns={"People":"People Coming Back Home"}, inplace=True)
reasons_go_home
# Out:
#       People Coming Back Home
# Year
# 2563                 116771.0
# 2564                 152247.0

# %%
reorder_total = pd.DataFrame(pivot_reason['Total']).sort_values(by=['Year','Total'], ascending=[True, False])
ptable_resetind = reorder_total.reset_index()
grouby_total = ptable_resetind.groupby('Immigration Reason')['Total'].sum().reset_index()

# %%
order = grouby_total.sort_values(by ='Total', ascending = False)['Immigration Reason'].unique().tolist()

migrate_year= sns.barplot(
            data = ptable_resetind, 
            x= 'Total', 
            y= 'Immigration Reason', 
            hue='Year', 
            order = order,
            palette = 'Greys')

plt.title('Migration Reasons Across Years for All Reasons', fontdict={'fontsize': 18})
plt.ylabel('Reason for Migration')
plt.xlabel('Number of People')
plt.tight_layout()
sns.move_legend(migrate_year, "upper left", bbox_to_anchor=(1, 1))

# %%
sorted_reason = reasons_6364.sort_values('People', ascending=False)["Immigration Reason"].unique()
color_mapping = {
    'Looking for a job': 'red',
    'Responsibility': 'red',
    'Changing job': 'red',
    'Need more revenue': 'red'
}

colored_reasons = ['red' if reason in color_mapping else '.8' for reason in sorted_reason]

# %%
migrate_reason = sns.barplot(data=reasons_6364.sort_values(['Year', 'People'], ascending=[True, False]),
                             x="Year",
                             y="People",
                             hue="Immigration Reason",
                             palette = colored_reasons,
                             errorbar=None,
                             estimator=sum,
                             )
migrate_reason.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f"{x/1000:,.1f}k"))
plt.title('Migration Reasons Across Years for All Reasons (Highlighted)', fontdict={'fontsize': 18})
sns.move_legend(migrate_reason, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# **ภาพกราฟแสดงให้เห็นถึงแนวโน้มการเพิ่มขึ้นของจำนวนผู้ย้ายถิ่นฐานในประเทศไทย แยกตามเหตุผลของปี 2563 และ 2564**
# - เหตุผลหลักของทั้ง 2 ปี คือ "การกลับภูมิลำเนา" โดยมีจำนวนการกลับภูมิลำเนาอยู่ที่ 116,771 และ 152,247 คน ในปี 2563, 2564 ตามลำดับ
# - แต่สิ่งที่น่าสนใจคือมีจำนวนคนที่ย้าย "เพราะหน้าที่การงาน" อยู่จำนวนไม่น้อย (4 เหตุผล ได้แก่ หางานทำ, ต้องการเปลี่ยนงาน, ต้องการรายได้เพิ่มเติม และ หน้าที่การงาน) ซึ่งรวมกันแล้วมีมากถึง 182,097 , 188,662 คน ในปี 2563, 2564 ตามลำดับ ซึ่งจะเห็นว่ามากกว่าการย้ายเพื่อ "กลับภูมิลำเนา" ที่เป็นเหตุผลหลักอยู่ประมาณ 60,000 และ 30,000 ในปี 2563, 2564 ตามลำดับ

# %%
@interact(Region=reasons_6364['Region'].unique())
def plot_chart(Region=reasons_6364['Region'].unique()):
    filtered_data = reasons_6364[reasons_6364['Region'] == Region]
    
    sns.catplot(
        data=filtered_data.sort_values("People", ascending=False),
        kind="bar",
        y="Immigration Reason",
        x="People",
        color=".7",
        col="Year",
        errorbar=None,
        palette="Greys_r",
        height=3.5,
        aspect=1.6,
        sharex=True,
    )
# Out:
# interactive(children=(Dropdown(description='Region', options=('Bangkok', 'Central', 'North', 'Notheast', 'Sout…

# %% [markdown]
# ## ประชากรแฝงกลางคืน
#
# แหล่งที่มาของข้อมูล
# - [หน้าหลักของข้อมูลสำรวจประชากรแฝง](https://www.nso.go.th/nsoweb/nso/survey_detail/yS)
# - เนื่องจากมีเพียงไฟล์ประเภท pdf เท่านั้น ทางกลุ่มจึงต้องรวบรวมจำนวนประชากรแฝงกลางคืนในกรุงเทพมหานคร 6 ปีย้อนหลังโดยการเปิดรายงานทุกฉบับ เลือกเพียงข้อมูลที่สนใจ แล้วบันทึกในรูป text
#     - [รายงานสำรวจประชากรแฝงปี 2565](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMTU4NDRfNzA0NjUucGRmIiwiZmlsZW5hbWUiOiJzdW1tYXJ5XzY1LnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2564](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMTU5MzBfODYyODYucGRmIiwiZmlsZW5hbWUiOiJzdW1tYXJ5XzY0LnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2563](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAwMjFfMjIyODIucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYzLnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2562](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAxMjFfMzYzNjgucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYyLnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2561](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAxNTRfNzY2MjcucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYxLnBkZiJ9)
#     - [รายงานสำรวจประชากรแฝงปี 2560](https://www.nso.go.th/nsoweb/download/eyJwYXRoIjoic3RvcmFnZVwvc3VydmV5X2RldGFpbFwvMjAyM1wvMjAyMzA1MDEwMjAyMjhfNjg3NjcucGRmIiwiZmlsZW5hbWUiOiJQb3B1bGF0aW9uXzYwLnBkZiJ9)
# ---
#
# อย่างที่ได้นำเสนอไปข้างต้น จะเห็นได้ว่ากรุงเทพฯ มีคนย้ายเข้าไปเฉลี่ยแล้วประมาณปีละ 40,000 คน แต่นั้นเป็นเพียงส่วนที่ย้ายถิ่นฐานไปด้วยการเปลี่ยนทะเบียนบ้านเท่านั้น แท้จริงแล้วกรุงเทพฯมีประการกรที่เป็น "[ประชากรแฝง](#definition)" อยู่จำนวนมาก โดยมีตารางและกราฟแสดงสถิติิจำนวนประชากรแฝงกลางคืนในกรุงเทพฯ ดังต่อไปนี้

# %%
night_pivot = night_pop.pivot_table(index="Year",values="Nighttime Shadow Population")
night_pivot.rename(columns={"Nighttime Shadow Population":"Nighttime Shadow Population in Bangkok"}, inplace=True)
night_pivot
# Out:
#       Nighttime Shadow Population in Bangkok
# Year
# 2560                                   2.050
# 2561                                   2.040
# 2562                                   2.270
# 2563                                   2.350
# 2564                                   2.324
# 2565                                   2.708

# %%
bargraph = sns.barplot(data=night_pop, x="Year", y="Nighttime Shadow Population", errorbar=None, color="gray")
bargraph.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f"{x}m"))
plt.title("Shadow Population In Bangkok", fontdict={'fontsize': 18});

# %% [markdown]
# เมื่อวิเคราะห์กับเวลาแล้วจะพบจำนวนประชากรแฝงในกรุงเทพมหานครว่ามีแนวโน้มเพิ่มมากขึ้น ซึ่งข้อมูลนี้แสดงให้เห็นว่า ถึงแม้จำนวนการย้ายเข้ากรุงเทพจะมีไม่เยอะ แต่จำนวนประชากรแฝงกลางคืนเพิ่มขึ้นทุกปี เป็นเพราะ สถิติการย้ายถิ่นฐาน เป็นสถิติของจำนวนคนที่ย้ายทะเบียนบ้าน แต่ประชากรแฝงกลางคืน คือ คนที่เข้าอยู่อาศัยในกรุงเทพโดยที่ไม่ได้ย้ายทะเบียนบ้าน ซึ่งการที่มีประชากรแฝงกลางคืนในกรุงเทพเพิ่มขึ้น หมายถึง คนจากต่างจังหวัดเดินทางมาใช้ชีวิตในกรุงเทพ ซึ่งอาจเป็น การหางาน เรียนหนังสือ หรือแต่งงาน เป็นต้น แต่ว่าคนเหล่านี้ไม่ได้ย้ายทะเบียนบ้าน

# %% [markdown]
# ## จำนวนผู้สูงอายุจากการสำรวจ จำแนกตามลักษณะการอยู่อาศัย กลุ่มอายุ เพศ
#
# แหล่งที่มาของข้อมูล
# - [หน้าหลักของข้อมูล จากสำนักงานสถิติแห่งชาติ](https://catalog.nso.go.th/dataset/os_01_00045/resource/c7b3b266-a884-47e1-b042-5d8eccce7d69)
# - [ลิงค์ข้อมูล](https://catalogapi.nso.go.th/api/index?table=OS_01_0045_15&format=csv)
# ---
#
# ต่อมาจะเป็นกราฟ สถิติผู้สูงอายุที่อยู่คนเดียว โดยจะแบ่งเป็นกลุ่มอายุ 60-69 ปี 70-79 ปี และ 80 ปีขึ้นไป จากปี 2550, 2557 และล่าสุดคือปี 2560

# %%
elders.pivot_table(values = "value", index = ['year', 'age_group', 'type_of_con_mat'], columns='sex')
# Out:
# sex                                 Female    Male
# year age_group     type_of_con_mat
# 2550 60-69 yrs old Alone            168659   87756
#      70-79 yrs old Alone            132351   81477
#      80+ yrs old   Alone             46761   21001
# 2557 60-69 yrs old Alone            266585  164865
#      70-79 yrs old Alone            200501   98820
#      80+ yrs old   Alone             90190   55037
# 2560 60-69 yrs old Alone            372371  224965
#      70-79 yrs old Alone            273640  137137
#      80+ yrs old   Alone            147470   67868

# %%
grid = sns.barplot(elders, x = 'year', 
                    hue = 'age_group', 
                    y = 'value', 
                    palette='Greys', 
                    errorbar=None, 
                    estimator=sum)
grid.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f"{x/1000:,.1f}k"))
plt.title("Elderly Lived Alone Population in Year 2550 2557 and 2560", fontdict={'fontsize': 18})
sns.move_legend(grid, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# จากกราฟแสดงให้เห็นว่ามีจำนวนผู้สูงอายุถูกทิ้งไว้มากขึ้นทุกปี ถ้าเราดูสถิติผู้สูงอายุที่อยู่คนเดียวควบคู่กับสถิติคนย้ายถิ่นฐานเข้าเมือง ก็จะพบความจริงว่า มีจำนวนประชากรไม่น้อยที่จำเป็นต้องออกจากบ้านเกิดไปหางานหรือโอกาสที่มีมากกว่าในเมืองเพื่อจะได้เงินมาใช้สำหรับในการเลี้ยงดูครอบครัว ส่งผลให้ผู้สูงอายุจำนวนมาก หรือพ่อแม่ตัวเองไว้ที่บ้านถูกทิ้งไว้อยู่คนเดียว ถ้าดูในปี 2560 มีผู้สูงอายุที่มีอายุ 80 ปีขึ้นไป มากกว่า 10,000 คน ที่ไม่สามารถช่วยเหลือตัวเองได้ และหลายท่านมีโรคประจำตัว ที่ต้องได้รับการรักษาและดูแลอย่างใกล้ชิด ยิ่งไปกว่านั้นในปี 2560 มีผู้สูงอายุในช่วงอายุ 60-79 ปี เกือบ 70,000 คน ที่กำลังจะเข้าสู่วัย 80 ปี หากไม่มีการแก้ไข ปัญหานี้จะทวีความรุนแรงขึ้นและจะมีกลุ่มอายุนี้ที่ไม่สามารถช่วยเหลือตัวเองได้ถูกทิ้งให้อยู่คนเดียวได้เป็นจำนวนมาก

# %% [markdown]
# ## อัตราเจริญพันธุ์
#
# แหล่งที่มาของข้อมูล
# - [หน้าหลักของข้อมูล จากสำนักงานสถิติแห่งชาติ](https://catalog.nso.go.th/dataset/os_01_00038/resource/bdd726a6-6c30-4081-b4d1-cbd5a45457dd)
# - [ลิงค์ข้อมูล](https://catalogapi.nso.go.th/api/index?table=OS_01_0038_01&format=csv)
# ---
#
# หลังจากที่เราพบว่ามีจำนวนคนย้ายถิ่นฐานด้วยเหตุผลที่เกี่ยวกับงานมากเป็นอันดับหนึ่ง และมีแนวโน้มเพิ่มขึ้น ประกอบกับจำนวนผู้สูงอายุที่ถูกทิ้งให้อยู่คนเดียวก็มีแนวโน้มสูงขึ้นทุกปีเช่นเดียวกัน เมื่อพบแบบนี้แล้ว ผู้อ่านอาจสงสัยว่าอาจเป็นเพราะปัจจัยประชากรทีมากขึ้นหรือไม่ที่ทำให้จำนวนคนย้ายถิ่นและจำนวนผู้สูงอายุสูงมีแนวโน้มสูงขึ้นทั้งคู่ จึงขอนำเสนอ **ข้อมูลอัตราเจริญพันธุ์** ย้อนหลังของประเทศไทยประกอบด้วย เพื่อทำให้เห็นภาพของปัญหาชัดเจนมากขึ้น โดยมีตารางและกราฟที่เกี่ยวข้องดังต่อไปนี้

# %%
fertility.pivot_table(index="year", values="percentage")
# Out:
#            percentage
# year
# 2517-2519        4.90
# 2528-2529        2.70
# 2538-2539        2.00
# 2548-2549        1.50
# 2558-2559        1.61

# %%
sns.barplot(fertility, x="percentage", y="year", color="gray")
plt.title("Fertility Rate In each Year Gap", fontdict={'fontsize': 18});

# %% [markdown]
# จาก bar chart จะแสดงให้เห็นว่ามี
# - อัตราเจริญพันธุ์มีแนวโน้มต่ำลงเรื่อยๆทุกปี (หน่วยเป็น จำนวนทารกเกิดใหม่คนต่อสตรีวัยเจริญพันธุ์หนึ่งคน)
# - โดยแนวโน้มดังกล่าว ชี้ให้เห็นว่าการที่จำนวนคนย้ายถิ่นและจำนวนผู้สูงอายุที่ถูกทอดทิ้งให้อยู่คนเดียวมากขึ้นนั้น ไม่ได้เป็นเพราะผลของจำนวนประชากรที่มากขึ้น แต่กลับกัน อัตราเจริญพันธุ์ของประเทศไทยน้อยลงอย่างเห็นได้ชัด และมีแนวโน้มน้อยลงในอนาคต
# - การเกิดที่ต่ำลงทำให้ขนาดครอบครัวเล็กลง ซึ่งแปลว่าจะมีจำนวนคนที่คอยช่วยเหลือ (care giver) ทั้งแรงกาย และเรื่องการเงินน้อยลง และเพิ่มโอากาสที่จะทำให้ผู้สูงอายุต้องอยู่คนเดียวในอนาคตมากขึ้น
# - นอกจากแรงกายและการช่วยเหลือทางครอบครัวแล้ว ทางกลุ่มเรายังคิดว่า การที่อัตราเจริญพันธุ์ต่ำลงอาจส่งผลให้ผู้สูงอายุที่อยู่คนเดียวเกิดความเหงามากขึ้นเพราะลูกไม่มีหลานให้กอด หรือฝากเลี้ยง ซึ่งเป็นสิ่งที่อยู่ในวัฒนธรรมไทยมานาน และอาจจะได้เห็นภาพเหล่านั้นน้อยลงในอนาคต

# %% [markdown]
# # Step 4 : Cause and Solution
# ---

# %% [markdown]
# หลังจากที่เราได้ดูและวิเคราะห์กราฟต่างๆ จากด้านบนแลัว ต่อมาเราจะมาดูสาเหตุและวิธีแก้ไขปัญหาใน เรื่องอ้ตราเจริญพันธุ์ที่ต่ำลงที่มีและคนย้ายเข้าเมือง ที่ส่งผลใน เรื่อง aging society
#
#
# > Causes
#
# * ต้นเหตุที่ทำให้อัตราเจริญพันธุ์ต่ำลง
#     * ต้นทุนชีวิตที่สูงขึ้นซึ่งไม่สอดคล้องกับค่าตอบแทนจากการทำงาน ซึ่งเป็นหนึ่งในปัจจัยที่สำคัญที่ทำให้คนรุ่นใหม่ส่วนใหญ่ตัดสินใจไม่มีลูก เพราะ เฉพาะการหาเงินเพื่อใช้เลี้ยงชีพก็ยากแล้ว
#       ถ้าเกิดมีลูกอีกก็จะส่งผลให้มีรายจ่ายที่เพิ่มขึ้นอีก
#     * คนรุ่นใหม่ส่วนใหญ่ให้ความสำคัญกับอิสระและความยืดหยุ่นในการใช้ชีวิต การมีลูกหมายถึงการมีภาระหน้าที่และความรับผิดชอบเพิ่มมากขึ้น ซึ่งอาจจำกัดเวลาส่วนตัวและโอกาสในการทำสิ่งที่ชอบ
#     * เมื่อมองในสถานการณ์ของประเทศไทย อีกหนึ่งปัจจัยที่ทำให้คนไม่อยากมีลูก อาจเป็นเรื่องการเมืองหรือเศรษฐกิจทีไม่มึความมั้นคงในประเทศ ซึ่งจะส่งผลกระทบต่อความเชื่อมั่นและการวางแผนอนาคตของประชาชน
#     กล่าวคือ เพราะหากเศรฐกิจและการเมืองไม่มั่นคงในอนาคต จะทำให้ครอบครัวซึ่งรวมถึงลูกมีความลำบาก ส่งผลให้คนไม่อยากมีลูก
#
# * ต้นเหตุสำคัญที่ทำให้คนต้องเข้าไปทำงานในเมืองมากขึ้นคือ **ปัญหาเมืองโตเดี่ยว**
#     *  โอกาสในการประกอบอาชีพและรายได้ที่สูงกว่าเมืองอื่นๆ  ด้วยความเป็นศูนย์กลางทางเศรษฐกิจ การเมือง การศึกษา และวัฒนธรรม กรุงเทพฯ ดึงดูดผู้คนจากทั่วประเทศให้เข้ามาหางานและแสวงหาโอกาสที่ดีกว่า
#     *  หนึ่งในแรงดึงดูดหลักของกรุงเทพมหานคร เช่น ระบบคมนาคมที่สะดวกกว่าต่างจังหวัด ซึ่งก็ทำให้ชีวิตสะดวกสบายมากขึ้น  นอกจากนี้ยังเป็นเรื่องของการเข้าถึงทรัพยากรต่างๆได้อย่างสะดวก เช่น ห้างสรรพสินค้า บริการต่างๆที่รองรับเพียงในกรุงเทพอย่างบริการ food delivery เป็นต้น
#
#
#
#
#
# > Solution
# - วิธีแก้ปัญหาอัตราเจริญพันธุ์ที่ต่ำลง
#     * เพิ่มสวัสดิการที่ช่วยให้คนมีลูกมากขึ้น เช่น การเพิ่มเงินช่วยเหลือค่าใช้จ่าย โดยเฉพาะช่วงวัยเด็กเล็ก, การอุดหนุนค่าศึกษาขั้นพื้นฐานฟรี และรวมไปถึงการช่วยเหลือค่าใช้จ่ายด้านอสังหาริมทรัพย์ เพื่อสนับสนุนให้คนรุ่นใหม่มีบ้านในราคาที่เข้าถึงได้ เหมาะกับการสร้างครอบครัว
#     * เพิ่มความเชื่อมั่นทางการเมือง แม้จะดูเป็นเรื่องเกินจะควบคุมได้ แต่รัฐบาลควรแสดงท่าทีและออกนโยบายเพื่อเพิ่มเสถียรภาพทางการเมืองมากขึ้น รวมไปการลดความขัดแย้งการทางการเมือง เพื่อทำให้คนรุ่นใหม่เชื่อว่า  ภาพในอนาคตเหมาะสมกับการสร้างครอบครัว
#
#
# - วิธีแก้ปัญหาคนย้ายเข้าเมือง
#     * กระจายอำนาจการปกครองสู่ท้องถิ่น โดยการให้คนในท้องถิ่นมีอำนาจในการเลือกคนที่จะบริหารการปกครองส่วนท้องถิ่นของตัวเอง เพื่อสะท้อนความต้องการของชุมชนอย่างแท้จริง
#     * เพิ่มผลตอบแทนเพื่อดึงดูดให้คนที่มีความสามารถกลับเข้าไปทำงานที่บ้านเกิดเพื่อพัฒนาบ้านเกิดของตัวเอง ซึ่งอาจจะเป็นการลดภาษี หรือลดดอกเบี้ยเงินกู้ให้กับบริษัทที่เปิด headquaters ที่ต่างจังหวัด เป็นต้น
#     * จัดสรรงบประมาณเพิ่มให้กับท้องถิ่น เพื่อให้ท้องถิ่นสามารถควบคุมการเก็บภาษี หรือจัดสรรงบประมาณได้อย่างมีอิสระมากขึ้น รวมไปถึงการจัดให้มีสาธารณูปโภคที่จำเป็นต่อการเติบโต เช่น ระบบขนส่งสาธารณะ เป็นต้น

# %% [markdown]
# # Step 5 : Summary
# ---
# จากกราฟต่างๆ รวมถึงปัญหาและสาเหตุที่กลุ่มเราได้วิเคราะห์และค้นพบ จึงทำให้สรุปได้ว่า ผลกระทบที่สำคัญของการย้ายถิ่นฐานที่มีต่อ aging society คือ ทำให้ผู้สูงอายุถูกทิ้งให้อยู่คนเดียวมากขึ้น ซึ่งสาเหตุที่ทำให้คนย้ายถิ่นฐานมีทั้งเรื่อง การหางาน การศึกษา หรือแม้กระทั่งการใช้ชีวิตที่มีความสะดวกสะบายกว่าต่างจังหวัด
# ไม่ว่าจะเป็นการย้ายถิ่นฐานแบบย้ายทะเบียนและไม่ย้ายทะเบียนบ้าน และนอกจากสาเหตุการย้ายถิ่นฐานแลัว ยังมีสาเหตุหลักที่อีกประการหนึ่งที่ทำให้ผู้สูงอายุถูกทิ้งไว้คนเดียว
# คือ เรื่องอัตราเจริญพันธุ์ที่ต่ำลง ที่เกิดขึ้นมาจาก การที่ต้นทุนชีวตคนสูงขึ้น คนส่วนมากชอบใช้ที่ชีวิตยืดหยุ่น หรือ สภาพเศรษฐกิจในประเทศ เป็นต้น ด้วยสาเหตุทั้งหมดนี้ จึงทำให้ต้องมีวิธีการรับมือที่เหมาะกับเหตุการณ์ที่เกิดใน aging society
